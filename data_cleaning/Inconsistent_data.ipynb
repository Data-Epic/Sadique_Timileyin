# %%
import gspread
import pandas as pd

gc = gspread.service_account("my-project.json")

sh = gc.open_by_url("https://docs.google.com/spreadsheets/d/1SUlcukpgxf6pfFQbj6DKQZXSlOhyBOSuBdbmQ2ZbhTM/edit#gid=1520648174")

worksheet = sh.worksheet("inconsistent_data")

# %%
dataframe = pd.DataFrame(worksheet.get_all_records())
dataframe
# Out:
#       S#                       Date                   Islamic Date  \
# 0      1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1      2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2      3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3      4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4      5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# ..   ...                        ...                            ...
# 491  492   Thursday-October-05-2017           13 MuHarram 1439 A.H
# 492  493   Thursday-October-19-2017           27 MuHarram 1439 A.H
# 493  494   Thursday-November-9-2017              19 Safar 1439 A.H
# 494  495    Friday-November-24-2017       5 Rabi Al-Awwal 1439 A.H
# 495  496  Saturday-November-25-2017       6 Rabi Al-Awwal 1439 A.H
#
#     Blast Day Type Holiday Type         Time       City   Latitude  Longitude  \
# 0          Holiday      Weekend          N/A  Islamabad     33.718    73.0718
# ...

# %%
df = dataframe.to_csv('InconsistentData.csv')

# %%
df = pd.read_csv('InconsistentData.csv')
df.head(50)
# Out:
#     Unnamed: 0  S#                       Date                   Islamic Date  \
# 0            0   1    Sunday-November 19-1995  25 Jumaada al-THaany 1416 A.H
# 1            1   2     Monday-November 6-2000           10 SHa`baan 1421 A.H
# 2            2   3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3            3   4        Friday-June 14-2002     3 Raby` al-THaany 1423 A.H
# 4            4   5         Friday-July 4-2003     4 Jumaada al-awal 1424 A.H
# 5            5   6  Thursday-December 25-2003      2 Thw al-Qi`dah 1424 A.H.
# 6            6   7  Saturday-February 28-2004            8 MuHarram 1425 A.H
# 7            7   8          Friday-May 7-2004      18 Raby` al-awal 1425 A.H
# 8            8   9         Monday-May 31-2004                            NaN
# 9            9  10       Thursday-June 3-2004    15 Raby` al-THaany 1425 A.H
# 10          10  11     Wednesday-July 28-2004  11 Jumaada al-THaany 1425 A.H
# ...

# %%
pd.set_option('display.max_columns', 43)

# %%
df.shape
# Out:
# (496, 27)

# %%
# df['Date'] = df['Date'].str.replace('August', 'Aug')
# df['Date'] = df['Date'].str.replace('September', 'Sep')
# df['Date'] = df['Date'].str.replace('January', 'Jan')
# df['Date'] = df['Date'].str.replace('October', 'Oct')
# df['Date'] = df['Date'].str.replace('June', 'Jun')
# df['Date'] = df['Date'].str.replace('July', 'Jul')
# df['Date'] = df['Date'].str.replace('November', 'Nov')
# df['Date'] = df['Date'].str.replace('December', 'Dec')
# df['Date'] = df['Date'].str.replace('April', 'Apr')
# df['Date'] = df['Date'].str.replace('Febuary', 'Feb')
# df['Date'] = df['Date'].str.replace('March', 'Mar')
df.head(50)
# Out:
#     Unnamed: 0  S#                       Date                   Islamic Date  \
# 0            0   1         Sunday-Nov 19-1995  25 Jumaada al-THaany 1416 A.H
# 1            1   2          Monday-Nov 6-2000           10 SHa`baan 1421 A.H
# 2            2   3       Wednesday-May 8-2002              25 safar 1423 A.H
# 3            3   4         Friday-Jun 14-2002     3 Raby` al-THaany 1423 A.H
# 4            4   5          Friday-Jul 4-2003     4 Jumaada al-awal 1424 A.H
# 5            5   6       Thursday-Dec 25-2003      2 Thw al-Qi`dah 1424 A.H.
# 6            6   7  Saturday-February 28-2004            8 MuHarram 1425 A.H
# 7            7   8          Friday-May 7-2004      18 Raby` al-awal 1425 A.H
# 8            8   9         Monday-May 31-2004                            NaN
# 9            9  10        Thursday-Jun 3-2004    15 Raby` al-THaany 1425 A.H
# 10          10  11      Wednesday-Jul 28-2004  11 Jumaada al-THaany 1425 A.H
# ...

# %%
# df['Date'] = df['Date'].str.replace('Thursay', 'Thursday')
# df['Date'] = pd.to_datetime(df['Date'])

# %%
df.tail(50)
# Out:
#      Unnamed: 0   S#       Date                 Islamic Date Blast Day Type  \
# 446         446  447 2015-06-06                          NaN        Weekend
# 447         447  448 2015-06-08                          NaN    Working Day
# 448         448  449 2015-06-11                          NaN    Working Day
# 449         449  450 2015-06-29                          NaN    Working Day
# 450         450  451 2015-07-17                          NaN        Holiday
# 451         451  452 2015-08-16                          NaN        Holiday
# 452         452  453 2015-08-27                          NaN    Working Day
# 453         453  454 2015-09-01                          NaN    Working Day
# 454         454  455 2015-09-20                          NaN        Holiday
# 455         455  456 2015-10-14                          NaN    Working Day
# 456         456  457 2015-10-22                          NaN        Holiday
# ...

# %%
# df['Hospital Names'] = df['Hospital Names'].str.replace('.', ',')
# Out:
# /var/folders/by/7zf7bnfn5x31kvfd7xxnlz5c0000gn/T/ipykernel_26598/4035852130.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Hospital Names'] = df['Hospital Names'].str.replace('.', ',')

# %%
# df.drop(columns='Explosive Weight (max)', inplace=True)
# df['Time'] = df['Time'].str.replace('.', ':')

# %%
# df[['Time1', 'delete', 'delete1']] = df['Time'].str.split('/',3, expand=True)
# Out:
# /var/folders/by/7zf7bnfn5x31kvfd7xxnlz5c0000gn/T/ipykernel_26598/2576133448.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['Time1', 'delete', 'delete1']] = df['Time'].str.split('/',3, expand=True)

# %%
# df.drop(columns=['delete', 'delete1'], inplace=True)
# df[['Time1', 'delete', 'delete1']] = df['Time'].str.split('/',3, expand=True)

# %%
# df[['Time2', 'delete']] = df['Time1'].str.split('-',2, expand=True).head(50)
# df.head(50)
# df.drop(columns='Time1', inplace=True)
# df['Time2'] = df['Time2'].str.replace('late night', '')
df.head(50)
# Out:
#     Unnamed: 0  S#       Date                   Islamic Date Blast Day Type  \
# 0            0   1 1995-11-19  25 Jumaada al-THaany 1416 A.H        Holiday
# 1            1   2 2000-11-06           10 SHa`baan 1421 A.H    Working Day
# 2            2   3 2002-05-08              25 safar 1423 A.H    Working Day
# 3            3   4 2002-06-14     3 Raby` al-THaany 1423 A.H    Working Day
# 4            4   5 2003-07-04     4 Jumaada al-awal 1424 A.H    Working Day
# 5            5   6 2003-12-25      2 Thw al-Qi`dah 1424 A.H.        Holiday
# 6            6   7 2004-02-28            8 MuHarram 1425 A.H    Working Day
# 7            7   8 2004-05-07      18 Raby` al-awal 1425 A.H    Working Day
# 8            8   9 2004-05-31                            NaN    Working Day
# 9            9  10 2004-06-03    15 Raby` al-THaany 1425 A.H    Working Day
# 10          10  11 2004-07-28  11 Jumaada al-THaany 1425 A.H    Working Day
# ...

# %%
# df.drop(columns="Time2", inplace= True)
df.to_csv("Inconsistent_Data.csv")
